# %%
df = pd.read_csv("enrollment2024.csv")

# %%
import plotly.express as px
import pandas as pd

df_long = df.melt(id_vars=['School Name', 'Lat', 'Long'], 
                  value_vars=['2021', '2022', '2023', '2024'], 
                  var_name='Year', value_name='Enrollment')

df_long = df_long.dropna(subset=['Enrollment'])

fig = px.scatter_mapbox(df_long, 
                        lat="Lat", 
                        lon="Long", 
                        size="Enrollment", 
                        hover_name="School Name", 
                        hover_data=["Year", "Enrollment"], 
                        animation_frame="Year", 
                        title="School Enrollment from 2021 to 2024",
                        mapbox_style="carto-positron", 
                        size_max=50, 
                        zoom=10)

fig.update_layout(margin={"r":0,"t":0,"l":0,"b":0})

fig.show()

# %%
df.head()
# Out:
#                   School Name       Level  \
# 0          Andover Elementary  Elementary
# 1        Chickasaw Elementary  Elementary
# 2  Cypress Springs Elementary  Elementary
# 3         Deerwood Elementary  Elementary
# 4      Eagle Creek Elementary  Elementary
#
#                               Coordinates        Lat       Long  2024  2023  \
# 0  28.508444765800295, -81.22252761474682  28.508445 -81.222528   629   NaN
# 1  28.525712964852453, -81.29534695322018  28.525713 -81.295347   540   NaN
# 2  28.516503261719492, -81.23535949865853  28.516503 -81.235360   615   NaN
# 3  28.524777830636886, -81.25553838640373  28.524778 -81.255538   470   NaN
# 4   28.36063195917985, -81.23952983673647  28.360632 -81.239530   820   NaN
#
#    2022  2021  Difference
# 0   NaN   NaN         629
# 1   NaN   NaN         540
# 2   NaN   NaN         615
# 3   NaN   NaN         470
# 4   NaN   NaN         820
